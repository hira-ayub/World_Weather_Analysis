# %%
# Import the requests library.
# %matplotlib inline
import requests
import random
import pandas as pd 
import matplotlib.pyplot as plt
import numpy as np
import json
import os 
#Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# Import timeit.
import timeit

# Import linear regression from the SciPy stats module.
from scipy.stats import linregress 

# Import the time module.
import time

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Call the function with 2000.
# %timeit latitudes(2000)
# Out:
# 2.72 ms ± 231 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 804,
#    'main': 'Clouds',
#    'description': 'overcast clouds',
#    'icon': '04n'}],
#  'base': 'stations',
#  'main': {'temp': 59.38,
#   'feels_like': 57.97,
#   'temp_min': 57,
#   'temp_max': 61,
#   'pressure': 1015,
#   'humidity': 63},
#  'visibility': 10000,
#  'wind': {'speed': 17.27, 'deg': 180},
#  'clouds': {'all': 90},
#  'dt': 1617234741,
#  'sys': {'type': 1,
#   'id': 3486,
#   'country': 'US',
#   'sunrise': 1617186472,
#   'sunset': 1617232107},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.

    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_desc,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lakatoro
# Processing Record 2 of Set 1 | port lincoln
# Processing Record 3 of Set 1 | provideniya
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | wajir
# Processing Record 6 of Set 1 | barrow
# Processing Record 7 of Set 1 | atlantic beach
# Processing Record 8 of Set 1 | armadale
# Processing Record 9 of Set 1 | zhireken
# Processing Record 10 of Set 1 | frederikshavn
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | deputatskiy
# Processing Record 13 of Set 1 | puerto ayora
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | illapel
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | mullaitivu
# City not found. Skipping...
# Processing Record 18 of Set 1 | hilo
# Processing Record 19 of Set 1 | bluff
# Processing Record 20 of Set 1 | port blair
# Processing Record 21 of Set 1 | makakilo city
# Processing Record 22 of Set 1 | dikson
# Processing Record 23 of Set 1 | hermanus
# Processing Record 24 of Set 1 | yelizovo
# Processing Record 25 of Set 1 | ngunguru
# Processing Record 26 of Set 1 | laramie
# Processing Record 27 of Set 1 | westport
# Processing Record 28 of Set 1 | gat
# Processing Record 29 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 1 | half moon bay
# Processing Record 31 of Set 1 | mecca
# Processing Record 32 of Set 1 | avarua
# Processing Record 33 of Set 1 | mutoko
# Processing Record 34 of Set 1 | butaritari
# Processing Record 35 of Set 1 | umm lajj
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | cotonou
# Processing Record 38 of Set 1 | treinta y tres
# Processing Record 39 of Set 1 | port hardy
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | bakel
# Processing Record 42 of Set 1 | plettenberg bay
# Processing Record 43 of Set 1 | ushuaia
# Processing Record 44 of Set 1 | klaksvik
# Processing Record 45 of Set 1 | las palmas
# Processing Record 46 of Set 1 | atuona
# Processing Record 47 of Set 1 | amapa
# Processing Record 48 of Set 1 | takoradi
# Processing Record 49 of Set 1 | mataura
# Processing Record 50 of Set 1 | chartres
# Processing Record 1 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 2 | mbandaka
# Processing Record 3 of Set 2 | trelew
# Processing Record 4 of Set 2 | chuy
# Processing Record 5 of Set 2 | kapaa
# Processing Record 6 of Set 2 | sitka
# Processing Record 7 of Set 2 | cape town
# Processing Record 8 of Set 2 | busselton
# Processing Record 9 of Set 2 | dalinghe
# City not found. Skipping...
# Processing Record 10 of Set 2 | klyuchi
# Processing Record 11 of Set 2 | rikitea
# Processing Record 12 of Set 2 | iqaluit
# Processing Record 13 of Set 2 | fairbanks
# Processing Record 14 of Set 2 | nikolskoye
# Processing Record 15 of Set 2 | tiksi
# Processing Record 16 of Set 2 | aksu
# Processing Record 17 of Set 2 | geraldton
# Processing Record 18 of Set 2 | sonoita
# Processing Record 19 of Set 2 | burns lake
# Processing Record 20 of Set 2 | port elizabeth
# Processing Record 21 of Set 2 | tiarei
# Processing Record 22 of Set 2 | henties bay
# Processing Record 23 of Set 2 | qandala
# Processing Record 24 of Set 2 | cockburn harbour
# City not found. Skipping...
# Processing Record 25 of Set 2 | qaanaaq
# Processing Record 26 of Set 2 | yanan
# City not found. Skipping...
# Processing Record 27 of Set 2 | gannan
# Processing Record 28 of Set 2 | viedma
# Processing Record 29 of Set 2 | acapulco
# Processing Record 30 of Set 2 | scarborough
# Processing Record 31 of Set 2 | basoko
# Processing Record 32 of Set 2 | cabo san lucas
# Processing Record 33 of Set 2 | iskateley
# Processing Record 34 of Set 2 | mayo
# Processing Record 35 of Set 2 | tidore
# City not found. Skipping...
# Processing Record 36 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 37 of Set 2 | penzance
# Processing Record 38 of Set 2 | zhigansk
# Processing Record 39 of Set 2 | ankang
# Processing Record 40 of Set 2 | hasaki
# Processing Record 41 of Set 2 | macusani
# Processing Record 42 of Set 2 | ust-nera
# Processing Record 43 of Set 2 | charters towers
# Processing Record 44 of Set 2 | placido de castro
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 2 | colac
# Processing Record 47 of Set 2 | veraval
# Processing Record 48 of Set 2 | yerbogachen
# Processing Record 49 of Set 2 | georgetown
# Processing Record 50 of Set 2 | port-de-paix
# City not found. Skipping...
# Processing Record 1 of Set 3 | east london
# Processing Record 2 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 3 | komsomolskiy
# Processing Record 4 of Set 3 | zhangjiakou
# Processing Record 5 of Set 3 | castro
# Processing Record 6 of Set 3 | albany
# Processing Record 7 of Set 3 | bredasdorp
# Processing Record 8 of Set 3 | meulaboh
# Processing Record 9 of Set 3 | sainte-rose
# Processing Record 10 of Set 3 | bendigo
# Processing Record 11 of Set 3 | vestmannaeyjar
# Processing Record 12 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 13 of Set 3 | ostrovnoy
# Processing Record 14 of Set 3 | rawson
# Processing Record 15 of Set 3 | bubaque
# Processing Record 16 of Set 3 | visby
# Processing Record 17 of Set 3 | saint george
# Processing Record 18 of Set 3 | san jose
# Processing Record 19 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 20 of Set 3 | sao joao da barra
# Processing Record 21 of Set 3 | san carlos de bariloche
# Processing Record 22 of Set 3 | upernavik
# Processing Record 23 of Set 3 | saskylakh
# Processing Record 24 of Set 3 | kruisfontein
# Processing Record 25 of Set 3 | ribeira brava
# Processing Record 26 of Set 3 | xiaoweizhai
# Processing Record 27 of Set 3 | mackenzie
# Processing Record 28 of Set 3 | khandbari
# Processing Record 29 of Set 3 | kaitangata
# Processing Record 30 of Set 3 | fershampenuaz
# Processing Record 31 of Set 3 | alta floresta
# Processing Record 32 of Set 3 | novyy urengoy
# Processing Record 33 of Set 3 | kodiak
# Processing Record 34 of Set 3 | bonito
# Processing Record 35 of Set 3 | hambantota
# Processing Record 36 of Set 3 | carnarvon
# Processing Record 37 of Set 3 | tuktoyaktuk
# Processing Record 38 of Set 3 | ranong
# Processing Record 39 of Set 3 | jamestown
# Processing Record 40 of Set 3 | arraial do cabo
# Processing Record 41 of Set 3 | cidreira
# Processing Record 42 of Set 3 | cherskiy
# Processing Record 43 of Set 3 | santiago
# Processing Record 44 of Set 3 | bonthe
# Processing Record 45 of Set 3 | jieshi
# Processing Record 46 of Set 3 | guerrero negro
# Processing Record 47 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 48 of Set 3 | bangkal
# Processing Record 49 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 50 of Set 3 | frontera
# Processing Record 1 of Set 4 | vaini
# Processing Record 2 of Set 4 | tura
# Processing Record 3 of Set 4 | cerritos
# Processing Record 4 of Set 4 | thompson
# Processing Record 5 of Set 4 | hovd
# Processing Record 6 of Set 4 | malaya vishera
# Processing Record 7 of Set 4 | kalevala
# Processing Record 8 of Set 4 | hobyo
# Processing Record 9 of Set 4 | dunedin
# Processing Record 10 of Set 4 | sur
# Processing Record 11 of Set 4 | goderich
# Processing Record 12 of Set 4 | turukhansk
# Processing Record 13 of Set 4 | tahe
# Processing Record 14 of Set 4 | eyl
# Processing Record 15 of Set 4 | viru
# Processing Record 16 of Set 4 | bingerville
# Processing Record 17 of Set 4 | bela
# Processing Record 18 of Set 4 | denpasar
# Processing Record 19 of Set 4 | ossora
# Processing Record 20 of Set 4 | beba
# Processing Record 21 of Set 4 | adrar
# Processing Record 22 of Set 4 | hobart
# Processing Record 23 of Set 4 | aykino
# Processing Record 24 of Set 4 | new norfolk
# Processing Record 25 of Set 4 | bonavista
# Processing Record 26 of Set 4 | benguela
# Processing Record 27 of Set 4 | san patricio
# Processing Record 28 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 29 of Set 4 | mvuma
# Processing Record 30 of Set 4 | shache
# Processing Record 31 of Set 4 | macon
# Processing Record 32 of Set 4 | havelock
# Processing Record 33 of Set 4 | catuday
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | maragogi
# Processing Record 36 of Set 4 | isangel
# Processing Record 37 of Set 4 | manggar
# Processing Record 38 of Set 4 | grindavik
# Processing Record 39 of Set 4 | kalianget
# Processing Record 40 of Set 4 | yeniseysk
# Processing Record 41 of Set 4 | hualmay
# Processing Record 42 of Set 4 | saint anthony
# Processing Record 43 of Set 4 | haines junction
# Processing Record 44 of Set 4 | tari
# Processing Record 45 of Set 4 | praia
# Processing Record 46 of Set 4 | chokurdakh
# Processing Record 47 of Set 4 | puerto del rosario
# Processing Record 48 of Set 4 | bethel
# Processing Record 49 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 4 | severo-kurilsk
# Processing Record 1 of Set 5 | kempten
# Processing Record 2 of Set 5 | mozarlandia
# Processing Record 3 of Set 5 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 4 of Set 5 | portland
# Processing Record 5 of Set 5 | sao filipe
# Processing Record 6 of Set 5 | andenes
# Processing Record 7 of Set 5 | tolaga bay
# Processing Record 8 of Set 5 | berdigestyakh
# Processing Record 9 of Set 5 | zyryanka
# Processing Record 10 of Set 5 | kavaratti
# Processing Record 11 of Set 5 | rocha
# Processing Record 12 of Set 5 | akonolinga
# Processing Record 13 of Set 5 | saint-pierre
# Processing Record 14 of Set 5 | saldanha
# Processing Record 15 of Set 5 | saravena
# Processing Record 16 of Set 5 | ketchikan
# Processing Record 17 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 18 of Set 5 | leczna
# Processing Record 19 of Set 5 | linqiong
# Processing Record 20 of Set 5 | waingapu
# Processing Record 21 of Set 5 | yatou
# Processing Record 22 of Set 5 | mamallapuram
# Processing Record 23 of Set 5 | esperance
# Processing Record 24 of Set 5 | lorengau
# Processing Record 25 of Set 5 | aklavik
# Processing Record 26 of Set 5 | mwene-ditu
# Processing Record 27 of Set 5 | ulladulla
# Processing Record 28 of Set 5 | ibra
# Processing Record 29 of Set 5 | dargaville
# Processing Record 30 of Set 5 | mahebourg
# Processing Record 31 of Set 5 | tilichiki
# Processing Record 32 of Set 5 | saquena
# Processing Record 33 of Set 5 | vila
# Processing Record 34 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 35 of Set 5 | mau aima
# City not found. Skipping...
# Processing Record 36 of Set 5 | ekhabi
# Processing Record 37 of Set 5 | pangnirtung
# Processing Record 38 of Set 5 | cavalcante
# Processing Record 39 of Set 5 | khatanga
# Processing Record 40 of Set 5 | minnedosa
# Processing Record 41 of Set 5 | asau
# Processing Record 42 of Set 5 | coahuayana
# Processing Record 43 of Set 5 | birjand
# Processing Record 44 of Set 5 | stephenville crossing
# Processing Record 45 of Set 5 | catazaja
# Processing Record 46 of Set 5 | rivers
# Processing Record 47 of Set 5 | sainte-anne-des-monts
# Processing Record 48 of Set 5 | padang
# Processing Record 49 of Set 5 | namatanai
# Processing Record 50 of Set 5 | bilma
# Processing Record 1 of Set 6 | jerome
# Processing Record 2 of Set 6 | waggaman
# Processing Record 3 of Set 6 | faya
# Processing Record 4 of Set 6 | caravelas
# Processing Record 5 of Set 6 | talcahuano
# Processing Record 6 of Set 6 | narok
# Processing Record 7 of Set 6 | hithadhoo
# Processing Record 8 of Set 6 | codrington
# Processing Record 9 of Set 6 | torbay
# Processing Record 10 of Set 6 | pauini
# Processing Record 11 of Set 6 | bandarbeyla
# Processing Record 12 of Set 6 | naze
# Processing Record 13 of Set 6 | harper
# Processing Record 14 of Set 6 | sunland park
# Processing Record 15 of Set 6 | mount gambier
# Processing Record 16 of Set 6 | capao bonito
# Processing Record 17 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 18 of Set 6 | jibuti
# Processing Record 19 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 20 of Set 6 | niquelandia
# Processing Record 21 of Set 6 | phalombe
# Processing Record 22 of Set 6 | aykhal
# Processing Record 23 of Set 6 | rotifunk
# Processing Record 24 of Set 6 | lebu
# Processing Record 25 of Set 6 | campos gerais
# Processing Record 26 of Set 6 | lagoa
# Processing Record 27 of Set 6 | nanortalik
# Processing Record 28 of Set 6 | magadan
# Processing Record 29 of Set 6 | letlhakane
# Processing Record 30 of Set 6 | coihaique
# Processing Record 31 of Set 6 | goma
# Processing Record 32 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 33 of Set 6 | ust-ilimsk
# Processing Record 34 of Set 6 | omboue
# Processing Record 35 of Set 6 | casper
# Processing Record 36 of Set 6 | airai
# Processing Record 37 of Set 6 | alofi
# Processing Record 38 of Set 6 | yar-sale
# Processing Record 39 of Set 6 | verkhoshizhemye
# Processing Record 40 of Set 6 | opuwo
# Processing Record 41 of Set 6 | armacao de pera
# Processing Record 42 of Set 6 | hay river
# Processing Record 43 of Set 6 | pisco
# Processing Record 44 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 45 of Set 6 | mufumbwe
# Processing Record 46 of Set 6 | abonnema
# Processing Record 47 of Set 6 | vao
# Processing Record 48 of Set 6 | bowen
# Processing Record 49 of Set 6 | saint-philippe
# Processing Record 50 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 1 of Set 7 | kanye
# Processing Record 2 of Set 7 | marzuq
# Processing Record 3 of Set 7 | norman wells
# Processing Record 4 of Set 7 | waitati
# Processing Record 5 of Set 7 | itarema
# Processing Record 6 of Set 7 | dicabisagan
# Processing Record 7 of Set 7 | muisne
# Processing Record 8 of Set 7 | deer lake
# Processing Record 9 of Set 7 | constitucion
# Processing Record 10 of Set 7 | longyearbyen
# Processing Record 11 of Set 7 | issoudun
# Processing Record 12 of Set 7 | mafinga
# Processing Record 13 of Set 7 | paita
# Processing Record 14 of Set 7 | nsanje
# Processing Record 15 of Set 7 | inhambane
# Processing Record 16 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 17 of Set 7 | mantua
# Processing Record 18 of Set 7 | asyut
# Processing Record 19 of Set 7 | walvis bay
# Processing Record 20 of Set 7 | tshikapa
# Processing Record 21 of Set 7 | avera
# Processing Record 22 of Set 7 | schiffweiler
# Processing Record 23 of Set 7 | bairiki
# Processing Record 24 of Set 7 | battle creek
# Processing Record 25 of Set 7 | ponta delgada
# Processing Record 26 of Set 7 | lasa
# Processing Record 27 of Set 7 | yamethin
# Processing Record 28 of Set 7 | poum
# Processing Record 29 of Set 7 | hirara
# Processing Record 30 of Set 7 | pontianak
# Processing Record 31 of Set 7 | cuajinicuilapa
# Processing Record 32 of Set 7 | gisborne
# Processing Record 33 of Set 7 | gobabis
# Processing Record 34 of Set 7 | kahului
# Processing Record 35 of Set 7 | tyup
# Processing Record 36 of Set 7 | pec
# Processing Record 37 of Set 7 | shenjiamen
# Processing Record 38 of Set 7 | fortuna
# Processing Record 39 of Set 7 | bereznik
# Processing Record 40 of Set 7 | pathein
# Processing Record 41 of Set 7 | umanday
# City not found. Skipping...
# Processing Record 42 of Set 7 | ponta do sol
# Processing Record 43 of Set 7 | chapais
# Processing Record 44 of Set 7 | huarmey
# Processing Record 45 of Set 7 | phan rang
# City not found. Skipping...
# Processing Record 46 of Set 7 | bozhou
# Processing Record 47 of Set 7 | necochea
# Processing Record 48 of Set 7 | lata
# Processing Record 49 of Set 7 | rundu
# Processing Record 50 of Set 7 | coquimbo
# Processing Record 1 of Set 8 | trairi
# Processing Record 2 of Set 8 | dodge city
# Processing Record 3 of Set 8 | talnakh
# Processing Record 4 of Set 8 | labuhan
# Processing Record 5 of Set 8 | hohhot
# Processing Record 6 of Set 8 | puri
# Processing Record 7 of Set 8 | ilulissat
# Processing Record 8 of Set 8 | nichinan
# Processing Record 9 of Set 8 | dongli
# Processing Record 10 of Set 8 | rongcheng
# Processing Record 11 of Set 8 | ahipara
# Processing Record 12 of Set 8 | inta
# Processing Record 13 of Set 8 | sai buri
# Processing Record 14 of Set 8 | camabatela
# Processing Record 15 of Set 8 | cap malheureux
# Processing Record 16 of Set 8 | khor
# Processing Record 17 of Set 8 | bonfim
# Processing Record 18 of Set 8 | ancud
# Processing Record 19 of Set 8 | muros
# Processing Record 20 of Set 8 | nalut
# Processing Record 21 of Set 8 | talakan
# Processing Record 22 of Set 8 | la joya
# Processing Record 23 of Set 8 | kuala krai
# City not found. Skipping...
# Processing Record 24 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 25 of Set 8 | victoria
# Processing Record 26 of Set 8 | bershet
# Processing Record 27 of Set 8 | pevek
# Processing Record 28 of Set 8 | datong
# Processing Record 29 of Set 8 | butte
# Processing Record 30 of Set 8 | araouane
# Processing Record 31 of Set 8 | bykivka
# Processing Record 32 of Set 8 | santa ana
# Processing Record 33 of Set 8 | corner brook
# Processing Record 34 of Set 8 | kavieng
# Processing Record 35 of Set 8 | ribeira grande
# Processing Record 36 of Set 8 | bar harbor
# Processing Record 37 of Set 8 | taseyevo
# Processing Record 38 of Set 8 | tanete
# Processing Record 39 of Set 8 | red bluff
# Processing Record 40 of Set 8 | calabar
# Processing Record 41 of Set 8 | faanui
# Processing Record 42 of Set 8 | sangar
# Processing Record 43 of Set 8 | joshimath
# Processing Record 44 of Set 8 | korla
# Processing Record 45 of Set 8 | bambous virieux
# Processing Record 46 of Set 8 | monte patria
# Processing Record 47 of Set 8 | baykit
# Processing Record 48 of Set 8 | independence
# Processing Record 49 of Set 8 | nome
# Processing Record 50 of Set 8 | hami
# Processing Record 1 of Set 9 | sampit
# Processing Record 2 of Set 9 | bollnas
# Processing Record 3 of Set 9 | general pico
# Processing Record 4 of Set 9 | kralendijk
# Processing Record 5 of Set 9 | aranos
# Processing Record 6 of Set 9 | muscatine
# Processing Record 7 of Set 9 | launceston
# Processing Record 8 of Set 9 | kennebunk
# Processing Record 9 of Set 9 | galicea mare
# Processing Record 10 of Set 9 | keffi
# Processing Record 11 of Set 9 | kaya
# Processing Record 12 of Set 9 | garowe
# Processing Record 13 of Set 9 | yithion
# City not found. Skipping...
# Processing Record 14 of Set 9 | polovinnoye
# Processing Record 15 of Set 9 | pochutla
# Processing Record 16 of Set 9 | marabba
# Processing Record 17 of Set 9 | manaure
# Processing Record 18 of Set 9 | saint-francois
# Processing Record 19 of Set 9 | dera bugti
# Processing Record 20 of Set 9 | san vicente
# Processing Record 21 of Set 9 | miri
# Processing Record 22 of Set 9 | tucuman
# Processing Record 23 of Set 9 | haibowan
# City not found. Skipping...
# Processing Record 24 of Set 9 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 9 | raudeberg
# Processing Record 26 of Set 9 | tongren
# Processing Record 27 of Set 9 | tuy hoa
# Processing Record 28 of Set 9 | zhengjiatun
# Processing Record 29 of Set 9 | acajutla
# Processing Record 30 of Set 9 | wattegama
# Processing Record 31 of Set 9 | touros
# Processing Record 32 of Set 9 | tuatapere
# Processing Record 33 of Set 9 | mendi
# Processing Record 34 of Set 9 | keetmanshoop
# Processing Record 35 of Set 9 | leningradskiy
# Processing Record 36 of Set 9 | iracoubo
# Processing Record 37 of Set 9 | nhulunbuy
# Processing Record 38 of Set 9 | hanko
# Processing Record 39 of Set 9 | luanda
# Processing Record 40 of Set 9 | boa vista
# Processing Record 41 of Set 9 | knysna
# Processing Record 42 of Set 9 | olafsvik
# Processing Record 43 of Set 9 | gurskoye
# City not found. Skipping...
# Processing Record 44 of Set 9 | kassala
# Processing Record 45 of Set 9 | clyde river
# Processing Record 46 of Set 9 | boljarovo
# City not found. Skipping...
# Processing Record 47 of Set 9 | mehamn
# Processing Record 48 of Set 9 | taoudenni
# Processing Record 49 of Set 9 | lluta
# Processing Record 50 of Set 9 | mandeville
# Processing Record 1 of Set 10 | husavik
# Processing Record 2 of Set 10 | kirakira
# Processing Record 3 of Set 10 | ocos
# Processing Record 4 of Set 10 | mahon
# Processing Record 5 of Set 10 | merauke
# Processing Record 6 of Set 10 | monchegorsk
# Processing Record 7 of Set 10 | bograd
# Processing Record 8 of Set 10 | zlitan
# Processing Record 9 of Set 10 | tchollire
# Processing Record 10 of Set 10 | belawan
# Processing Record 11 of Set 10 | atar
# Processing Record 12 of Set 10 | sal rei
# Processing Record 13 of Set 10 | newport
# Processing Record 14 of Set 10 | tomatlan
# Processing Record 15 of Set 10 | mbaiki
# Processing Record 16 of Set 10 | hofn
# Processing Record 17 of Set 10 | torata
# Processing Record 18 of Set 10 | sayyan
# Processing Record 19 of Set 10 | salamiyah
# Processing Record 20 of Set 10 | virden
# Processing Record 21 of Set 10 | high rock
# Processing Record 22 of Set 10 | lavrentiya
# Processing Record 23 of Set 10 | agadez
# Processing Record 24 of Set 10 | collie
# Processing Record 25 of Set 10 | santa cruz
# Processing Record 26 of Set 10 | sabang
# Processing Record 27 of Set 10 | yulara
# Processing Record 28 of Set 10 | tsaratanana
# Processing Record 29 of Set 10 | souillac
# Processing Record 30 of Set 10 | beringovskiy
# Processing Record 31 of Set 10 | dingle
# Processing Record 32 of Set 10 | batagay-alyta
# Processing Record 33 of Set 10 | bitlis
# Processing Record 34 of Set 10 | vostok
# Processing Record 35 of Set 10 | nguiu
# City not found. Skipping...
# Processing Record 36 of Set 10 | te anau
# Processing Record 37 of Set 10 | tsabong
# Processing Record 38 of Set 10 | san andres
# Processing Record 39 of Set 10 | loikaw
# Processing Record 40 of Set 10 | malayal
# Processing Record 41 of Set 10 | kargasok
# Processing Record 42 of Set 10 | alcaniz
# Processing Record 43 of Set 10 | narsaq
# Processing Record 44 of Set 10 | nehe
# Processing Record 45 of Set 10 | phibun mangsahan
# Processing Record 46 of Set 10 | dhanbad
# Processing Record 47 of Set 10 | krasnoselkup
# Processing Record 48 of Set 10 | moree
# Processing Record 49 of Set 10 | dannenberg
# Processing Record 50 of Set 10 | paamiut
# Processing Record 1 of Set 11 | ormara
# Processing Record 2 of Set 11 | mudgee
# Processing Record 3 of Set 11 | wenling
# Processing Record 4 of Set 11 | rumoi
# Processing Record 5 of Set 11 | mindelo
# Processing Record 6 of Set 11 | vila velha
# Processing Record 7 of Set 11 | arouca
# Processing Record 8 of Set 11 | aksehir
# Processing Record 9 of Set 11 | mananara
# Processing Record 10 of Set 11 | ternate
# Processing Record 11 of Set 11 | mys shmidta
# City not found. Skipping...
# Processing Record 12 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 13 of Set 11 | moron
# Processing Record 14 of Set 11 | matara
# Processing Record 15 of Set 11 | korem
# Processing Record 16 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 17 of Set 11 | jabiru
# City not found. Skipping...
# Processing Record 18 of Set 11 | de-kastri
# Processing Record 19 of Set 11 | morrope
# Processing Record 20 of Set 11 | buraydah
# Processing Record 21 of Set 11 | thunder bay
# Processing Record 22 of Set 11 | dzhebariki-khaya
# Processing Record 23 of Set 11 | teya
# Processing Record 24 of Set 11 | roald
# Processing Record 25 of Set 11 | victor harbor
# Processing Record 26 of Set 11 | noumea
# Processing Record 27 of Set 11 | saleaula
# City not found. Skipping...
# Processing Record 28 of Set 11 | safford
# Processing Record 29 of Set 11 | sorong
# Processing Record 30 of Set 11 | karkaralinsk
# City not found. Skipping...
# Processing Record 31 of Set 11 | nemuro
# Processing Record 32 of Set 11 | yarada
# Processing Record 33 of Set 11 | ust-maya
# Processing Record 34 of Set 11 | thomaston
# Processing Record 35 of Set 11 | praya
# Processing Record 36 of Set 11 | neyshabur
# Processing Record 37 of Set 11 | zaigrayevo
# Processing Record 38 of Set 11 | boguchany
# Processing Record 39 of Set 11 | kieta
# Processing Record 40 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 41 of Set 11 | derzhavinsk
# Processing Record 42 of Set 11 | chipinge
# Processing Record 43 of Set 11 | alberton
# Processing Record 44 of Set 11 | maceio
# Processing Record 45 of Set 11 | scottsbluff
# Processing Record 46 of Set 11 | zheleznogorsk
# Processing Record 47 of Set 11 | nacala
# Processing Record 48 of Set 11 | sadiqabad
# Processing Record 49 of Set 11 | eydhafushi
# Processing Record 50 of Set 11 | neuquen
# Processing Record 1 of Set 12 | oktyabrskiy
# Processing Record 2 of Set 12 | jiaxing
# Processing Record 3 of Set 12 | hamilton
# Processing Record 4 of Set 12 | bentong
# Processing Record 5 of Set 12 | barsovo
# Processing Record 6 of Set 12 | mildura
# Processing Record 7 of Set 12 | dobryatino
# Processing Record 8 of Set 12 | pimentel
# Processing Record 9 of Set 12 | odienne
# Processing Record 10 of Set 12 | mombetsu
# Processing Record 11 of Set 12 | marawi
# Processing Record 12 of Set 12 | rosarito
# Processing Record 13 of Set 12 | orlik
# Processing Record 14 of Set 12 | imbituba
# Processing Record 15 of Set 12 | kambove
# Processing Record 16 of Set 12 | yirol
# City not found. Skipping...
# Processing Record 17 of Set 12 | pyapon
# Processing Record 18 of Set 12 | san luis
# Processing Record 19 of Set 12 | ouro branco
# Processing Record 20 of Set 12 | safaga
# Processing Record 21 of Set 12 | ruwi
# Processing Record 22 of Set 12 | timbiqui
# Processing Record 23 of Set 12 | baghdad
# Processing Record 24 of Set 12 | yol
# Processing Record 25 of Set 12 | sembe
# Processing Record 26 of Set 12 | buckingham
# Processing Record 27 of Set 12 | vanimo
# Processing Record 28 of Set 12 | sakakah
# Processing Record 29 of Set 12 | yenagoa
# Processing Record 30 of Set 12 | luderitz
# Processing Record 31 of Set 12 | palenque
# Processing Record 32 of Set 12 | prijepolje
# Processing Record 33 of Set 12 | cayenne
# Processing Record 34 of Set 12 | kedrovyy
# Processing Record 35 of Set 12 | mentok
# City not found. Skipping...
# Processing Record 36 of Set 12 | vanderhoof
# Processing Record 37 of Set 12 | barreiras
# Processing Record 38 of Set 12 | filadelfia
# Processing Record 39 of Set 12 | khandyga
# Processing Record 40 of Set 12 | stoyba
# City not found. Skipping...
# Processing Record 41 of Set 12 | buala
# Processing Record 42 of Set 12 | srednekolymsk
# Processing Record 43 of Set 12 | banda aceh
# Processing Record 44 of Set 12 | pinsk
# Processing Record 45 of Set 12 | baruun-urt
# Processing Record 46 of Set 12 | kindia
# Processing Record 47 of Set 12 | batemans bay
# Processing Record 48 of Set 12 | mato verde
# Processing Record 49 of Set 12 | burewala
# Processing Record 50 of Set 12 | teramo
# Processing Record 1 of Set 13 | oranjestad
# Processing Record 2 of Set 13 | chegdomyn
# Processing Record 3 of Set 13 | tignere
# Processing Record 4 of Set 13 | zacatepec
# Processing Record 5 of Set 13 | alice springs
# Processing Record 6 of Set 13 | shibetsu
# Processing Record 7 of Set 13 | slave lake
# Processing Record 8 of Set 13 | dhing
# Processing Record 9 of Set 13 | amos
# Processing Record 10 of Set 13 | niono
# Processing Record 11 of Set 13 | charlestown
# Processing Record 12 of Set 13 | sitia
# Processing Record 13 of Set 13 | bathurst
# Processing Record 14 of Set 13 | shimoda
# Processing Record 15 of Set 13 | north bend
# Processing Record 16 of Set 13 | laborie
# Processing Record 17 of Set 13 | itacarambi
# Processing Record 18 of Set 13 | ulaangom
# Processing Record 19 of Set 13 | liwale
# Processing Record 20 of Set 13 | berlevag
# Processing Record 21 of Set 13 | oyama
# Processing Record 22 of Set 13 | dera din panah
# City not found. Skipping...
# Processing Record 23 of Set 13 | mayskiy
# Processing Record 24 of Set 13 | aljezur
# Processing Record 25 of Set 13 | nobeoka
# Processing Record 26 of Set 13 | kathu
# Processing Record 27 of Set 13 | changying
# Processing Record 28 of Set 13 | kuji
# Processing Record 29 of Set 13 | namibe
# Processing Record 30 of Set 13 | inuvik
# Processing Record 31 of Set 13 | voyvozh
# Processing Record 32 of Set 13 | prescott
# Processing Record 33 of Set 13 | bathsheba
# Processing Record 34 of Set 13 | innisfail
# Processing Record 35 of Set 13 | martapura
# Processing Record 36 of Set 13 | shushenskoye
# Processing Record 37 of Set 13 | jadu
# Processing Record 38 of Set 13 | diu
# Processing Record 39 of Set 13 | bethanien
# Processing Record 40 of Set 13 | rio gallegos
# Processing Record 41 of Set 13 | kharp
# Processing Record 42 of Set 13 | kamaishi
# Processing Record 43 of Set 13 | magadi
# Processing Record 44 of Set 13 | chiungutwa
# Processing Record 45 of Set 13 | yongan
# Processing Record 46 of Set 13 | katsuura
# Processing Record 47 of Set 13 | svetlogorsk
# Processing Record 48 of Set 13 | paradwip
# City not found. Skipping...
# Processing Record 49 of Set 13 | karratha
# Processing Record 50 of Set 13 | fukue
# Processing Record 1 of Set 14 | paragominas
# Processing Record 2 of Set 14 | amurzet
# Processing Record 3 of Set 14 | anadyr
# Processing Record 4 of Set 14 | kasongo-lunda
# Processing Record 5 of Set 14 | dasoguz
# Processing Record 6 of Set 14 | horta
# Processing Record 7 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 8 of Set 14 | melioratorov
# Processing Record 9 of Set 14 | mahadday weyne
# City not found. Skipping...
# Processing Record 10 of Set 14 | kenora
# Processing Record 11 of Set 14 | beloha
# Processing Record 12 of Set 14 | senec
# Processing Record 13 of Set 14 | qasigiannguit
# Processing Record 14 of Set 14 | nyurba
# Processing Record 15 of Set 14 | kutum
# Processing Record 16 of Set 14 | poronaysk
# Processing Record 17 of Set 14 | koutsouras
# Processing Record 18 of Set 14 | kyabe
# Processing Record 19 of Set 14 | mahajanga
# Processing Record 20 of Set 14 | xining
# Processing Record 21 of Set 14 | celestun
# Processing Record 22 of Set 14 | zhenhai
# Processing Record 23 of Set 14 | manokwari
# Processing Record 24 of Set 14 | kizema
# Processing Record 25 of Set 14 | kuytun
# Processing Record 26 of Set 14 | pitimbu
# Processing Record 27 of Set 14 | ialibu
# Processing Record 28 of Set 14 | madhupur
# Processing Record 29 of Set 14 | ferme-neuve
# Processing Record 30 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 31 of Set 14 | naguabo
# Processing Record 32 of Set 14 | abu samrah
# Processing Record 33 of Set 14 | nishihara
# Processing Record 34 of Set 14 | ust-tsilma
# Processing Record 35 of Set 14 | lompoc
# Processing Record 36 of Set 14 | tabarqah
# City not found. Skipping...
# Processing Record 37 of Set 14 | the valley
# Processing Record 38 of Set 14 | mount isa
# Processing Record 39 of Set 14 | subaytilah
# City not found. Skipping...
# Processing Record 40 of Set 14 | bjornevatn
# Processing Record 41 of Set 14 | abeche
# Processing Record 42 of Set 14 | erenhot
# Processing Record 43 of Set 14 | san felipe
# Processing Record 44 of Set 14 | bilibino
# Processing Record 45 of Set 14 | hervey bay
# Processing Record 46 of Set 14 | sterling
# Processing Record 47 of Set 14 | ewa beach
# Processing Record 48 of Set 14 | eskisehir
# Processing Record 49 of Set 14 | lethem
# Processing Record 50 of Set 14 | dinga
# Processing Record 1 of Set 15 | soyo
# Processing Record 2 of Set 15 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 15 | dali
# Processing Record 4 of Set 15 | gorontalo
# Processing Record 5 of Set 15 | mocuba
# Processing Record 6 of Set 15 | coetupo
# City not found. Skipping...
# Processing Record 7 of Set 15 | dongsheng
# Processing Record 8 of Set 15 | salalah
# Processing Record 9 of Set 15 | san rafael
# Processing Record 10 of Set 15 | maniitsoq
# Processing Record 11 of Set 15 | udachnyy
# Processing Record 12 of Set 15 | smithers
# Processing Record 13 of Set 15 | beira
# Processing Record 14 of Set 15 | biskamzha
# Processing Record 15 of Set 15 | lagos
# Processing Record 16 of Set 15 | sao jose da coroa grande
# Processing Record 17 of Set 15 | champerico
# Processing Record 18 of Set 15 | lakhtar
# Processing Record 19 of Set 15 | salinopolis
# Processing Record 20 of Set 15 | mbini
# Processing Record 21 of Set 15 | bayan
# Processing Record 22 of Set 15 | tonj
# Processing Record 23 of Set 15 | yulin
# Processing Record 24 of Set 15 | yanggu
# Processing Record 25 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 26 of Set 15 | brufut
# Processing Record 27 of Set 15 | mandalgovi
# Processing Record 28 of Set 15 | general roca
# Processing Record 29 of Set 15 | vardo
# Processing Record 30 of Set 15 | jiddah
# City not found. Skipping...
# Processing Record 31 of Set 15 | quimper
# Processing Record 32 of Set 15 | medicine hat
# Processing Record 33 of Set 15 | cockburn town
# Processing Record 34 of Set 15 | alyangula
# Processing Record 35 of Set 15 | goure
# Processing Record 36 of Set 15 | najran
# Processing Record 37 of Set 15 | pierre
# Processing Record 38 of Set 15 | comodoro rivadavia
# Processing Record 39 of Set 15 | dzilam gonzalez
# Processing Record 40 of Set 15 | chagda
# City not found. Skipping...
# Processing Record 41 of Set 15 | nuuk
# Processing Record 42 of Set 15 | vestmanna
# Processing Record 43 of Set 15 | jega
# Processing Record 44 of Set 15 | morant bay
# Processing Record 45 of Set 15 | limoux
# Processing Record 46 of Set 15 | jutai
# Processing Record 47 of Set 15 | tabou
# Processing Record 48 of Set 15 | corrente
# Processing Record 49 of Set 15 | junin
# Processing Record 50 of Set 15 | lambarene
# Processing Record 1 of Set 16 | macaparana
# Processing Record 2 of Set 16 | arraias
# Processing Record 3 of Set 16 | auki
# Processing Record 4 of Set 16 | maturin
# Processing Record 5 of Set 16 | bac lieu
# Processing Record 6 of Set 16 | george town
# Processing Record 7 of Set 16 | venado tuerto
# Processing Record 8 of Set 16 | fergus falls
# Processing Record 9 of Set 16 | gamba
# Processing Record 10 of Set 16 | biltine
# Processing Record 11 of Set 16 | balykshi
# Processing Record 12 of Set 16 | conceicao do araguaia
# Processing Record 13 of Set 16 | chongwe
# Processing Record 14 of Set 16 | minna
# Processing Record 15 of Set 16 | maglajani
# Processing Record 16 of Set 16 | kusti
# Processing Record 17 of Set 16 | broome
# Processing Record 18 of Set 16 | dedougou
# Processing Record 19 of Set 16 | balkanabat
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# tally the number of cities in the city_data array
len(city_data)
# Out:
# 710

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Lakatoro -16.0999  167.4164     82.99        75          99
# 1    Port Lincoln -34.7333  135.8667     76.35        40          77
# 2     Provideniya  64.3833 -173.3000      6.80        66           0
# 3        Tasiilaq  65.6145  -37.6368     28.40        86          37
# 4           Wajir   1.7471   40.0573     81.48        62          57
# 5          Barrow  71.2906 -156.7887     -5.80        59           1
# 6  Atlantic Beach  30.3344  -81.3987     77.00        88          40
# 7        Armadale -32.1500  116.0000     72.00        68          98
# 8        Zhireken  52.8249  117.3076     25.48        60          47
# 9   Frederikshavn  57.4407   10.5366     44.01       100          90
#
#    Wind Speed Country Current Description                 Date
# 0        7.58      VU     overcast clouds  2021-03-31 23:54:22
# 1        4.94      AU       broken clouds  2021-03-31 23:54:22
# 2        4.47      RU           clear sky  2021-03-31 23:54:23
# 3        9.22      GL    scattered clouds  2021-03-31 23:54:23
# 4       14.38      KE       broken clouds  2021-03-31 23:48:43
# 5       24.16      US           clear sky  2021-03-31 23:49:38
# 6       10.36      US    scattered clouds  2021-03-31 23:54:24
# 7        8.05      AU     overcast clouds  2021-03-31 23:52:39
# 8        0.92      RU    scattered clouds  2021-03-31 23:54:24
# 9        5.75      DK          light rain  2021-03-31 23:54:25

# %%
#New Colum order
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        Lakatoro      VU -16.0999  167.4164     82.99        75          99
# 1    Port Lincoln      AU -34.7333  135.8667     76.35        40          77
# 2     Provideniya      RU  64.3833 -173.3000      6.80        66           0
# 3        Tasiilaq      GL  65.6145  -37.6368     28.40        86          37
# 4           Wajir      KE   1.7471   40.0573     81.48        62          57
# ..            ...     ...      ...       ...       ...       ...         ...
# 705     Maglajani      BA  44.9486   17.3494     48.20        87           0
# 706         Kusti      SD  13.1629   32.6635     79.63        11          42
# 707        Broome      US  42.2506  -75.8330     45.00        93          90
# 708      Dedougou      BF  12.4667   -3.4667     82.78        13           1
# 709    Balkanabat      TM  39.5108   54.3671     53.02        37          75
#
#      Wind Speed Current Description
# 0          7.58     overcast clouds
# 1          4.94       broken clouds
# 2          4.47           clear sky
# 3          9.22    scattered clouds
# 4         14.38       broken clouds
# ..          ...                 ...
# 705        2.30           clear sky
# 706       14.32    scattered clouds
# 707       14.97     overcast clouds
# 708        8.25           clear sky
# 709       21.25       broken clouds
#
# [710 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
